# %%
import geopandas as gpd
import pandas as pd

# %%
# 1. Check GeoJSON attributes
gdf = gpd.read_file("../data/edinburgh_iz_boundaries.geojson")
print("GeoJSON columns:", list(gdf.columns))

# 2. Check Forecast CSV attributes
df = pd.read_csv("../data/future_forecast_20230304.csv")
print("Forecast CSV columns:", list(df.columns))
# Out:
# GeoJSON columns: ['iz_code', 'iz_name', 'node_index', 'source_crs', 'web_crs', 'geometry']
# Forecast CSV columns: ['issue_date', 'target_report_date', 'update_id', 'checkpoint_id', 'iz_code', 'node_index', 'anchor_rate_y_t', 'predicted_delta', 'predicted_rate', 'predicted_variance', 'predicted_sigma', 'calibrated80_lower', 'calibrated80_upper', 'calibrated95_lower', 'calibrated95_upper', 'uncertainty_flag', 'alpha_geo', 'alpha_transport', 'alpha_mobility', 'node_order_hash', 'forecast_status', 'observed_target_available', 'include_in_metrics', 'observed_rate', 'model_error', 'model_absolute_error', 'persistence_prediction', 'persistence_absolute_error']
